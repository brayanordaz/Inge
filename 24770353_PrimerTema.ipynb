# %% [markdown]
# **Lenguaje y Algoritmo**
#
# Lenguaje de programacion:
#
#
#
# * C
# * C++
# * Java
# * Fortran
# * Delphi
#
# **Algoritmo**
# Conjunto de pasos, procedimiento o acciones que nos permiten alcanzar un resultado o resolver un problema.
#
# Caracteristicas:
#
# Determinismo:. Teoría que supone que el desarrollo de los fenómenos naturales está necesariamente determinado por las condiciones iniciales.
# Precision:
# Finitud.
#
# (Cairo et al., 1993)
#
# **Datos Numericos **
#
# Valores enteros y valores reales:
# Valores enteros pueden estar procedidos por los signos ( + - )
# 128 152s -714 8 530 -14 789
# 7.5 128.0 -37.865 129.7 16 000.50
#
# **Datos Alfanumericos**
# *Caracter
# *Cadena
# (a,b,c....z)
# (0, 1, 2, 3....9)
# (#, ?, %, *, etc)
# Caracter.
# 'a'  'B' '$' '9'
#
# **Datos tipo cadena**
# "abc" "$9#7" "heeeectooor" "Patroclio!!!" "754-27-22"
# **Datos Logicos**
# Verdadero(true)
# Falso(False)

# %%
#tipos de Variable en Python
#El tipo de variable estara determinado por el tipo de dato que almacena
#Enteros: vasta agregar un valor entero
a=10
b=11
c=a+b


#Decimales: deben agregarse un numero con punto flotante
c=3.1416

#Booleanos: Datos con cerdadero y falso
#Se pueden usar palabras: True y False
verdad=True
falso=False

Verdad=1
Falso=0

#Texto o cadena o string
saludo="Hola Mundo"
nombre="Brayan"
uno='a'
dos='b'
print(a)
print(b)
print(c)
print(verdad)
print(falso)
print(saludo)
print(nombre)
print(uno)
print(dos)
# Out:
# 10
# 11
# 3.1416
# True
# False
# Hola Mundo
# Brayan
# a
# b
